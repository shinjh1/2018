# %%
import csv
import matplotlib.pyplot as plt
f = open('1.csv')
f1 = open('2.csv')
f2 = open('3.csv')
f3 = open('4.csv')
f4 = open('5.csv')
f5 = open('6.csv')
f6 = open('7.csv')
f7 = open('8.csv')
f8 = open('9.csv')
f9 = open('10.csv')
f10 = open('11.csv')
f11 = open('12.csv')
f12 = open('e32.csv')

pmlist = []
hhklist = []

data = csv.reader(f)

for row in data : 
    if ' 12' in row[0] :
        pmlist. append(row)

data = csv.reader(f1)

for row in data : 
    if ' 12' in row[0] :
        pmlist. append(row)
        
data = csv.reader(f2)

for row in data : 
    if ' 12' in row[0] :
        pmlist. append(row)
        
data = csv.reader(f3)

for row in data : 
    if ' 12' in row[0] :
        pmlist. append(row)
        
data = csv.reader(f4)

for row in data : 
    if ' 12' in row[0] :
        pmlist. append(row)
        
data = csv.reader(f5)

for row in data : 
    if ' 12' in row[0] :
        pmlist. append(row)
        
data = csv.reader(f6)

for row in data : 
    if ' 12' in row[0] :
        pmlist. append(row)
        
data = csv.reader(f7)

for row in data : 
    if ' 12' in row[0] :
        pmlist. append(row)
        
data = csv.reader(f8)

for row in data : 
    if ' 12' in row[0] :
        pmlist. append(row)
        
data = csv.reader(f9)

for row in data : 
    if ' 12' in row[0] :
        pmlist. append(row)
        
data = csv.reader(f10)

for row in data : 
    if ' 12' in row[0] :
        pmlist. append(row)
        
data = csv.reader(f11)

for row in data : 
    if ' 12' in row[0] :
        pmlist. append(row)

result = []
for row in pmlist :
    result.append(row[9])
            
plt.plot(result)
plt.show()
